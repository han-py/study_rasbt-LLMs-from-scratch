# %% [markdown]
# ### 题目1

# %%
import torch

tensor_A = torch.rand(7, 7)
# print(tensor_A)
print(tensor_A.shape)
print(tensor_A.dtype)
# Out:
# torch.Size([7, 7])
# torch.float32

# %% [markdown]
# ### 题目2

# %%
tensor_B = torch.rand(1, 7)
tensor_C = tensor_A @ tensor_B
print(tensor_C.shape)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 2
#       1 tensor_B = torch.rand(1, 7)
# ----> 2 tensor_C = tensor_A @ tensor_B
#       3 print(tensor_C.shape)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (7x7 and 1x7)

# %%
tensor_B = torch.rand(1, 7)
tensor_C =  tensor_B @ tensor_A
print(tensor_C.shape)
# Out:
# torch.Size([1, 7])

# %% [markdown]
# ### 题目3

# %%
print(tensor_C.T.shape)
# Out:
# torch.Size([7, 1])

# %%
print(tensor_C.reshape(7, 1).shape)
# Out:
# torch.Size([7, 1])

# %%
print(tensor_C.view(7, 1).shape)
# Out:
# torch.Size([7, 1])

# %% [markdown]
# ### 题目4

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
tensor_C = tensor_C.to(device)
print(tensor_C.device)
# Out:
# cuda:0
