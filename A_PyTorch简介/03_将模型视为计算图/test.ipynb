# %% [markdown]
# ### 练习1

# %%
import torch

a = torch.tensor(2.0, requires_grad=True)
b = torch.tensor(3.0)
c = a * b
print(c)

print(a.requires_grad)
print(b.requires_grad)
print(c.requires_grad)
# Out:
# tensor(6., grad_fn=<MulBackward0>)
# True
# False
# True

# %% [markdown]
# ### 练习2

# %%
import torch

x = torch.tensor(4.0, requires_grad=True)
y = x ** 2 + 3 * x + 1

y.backward()
print(x.grad)
# Out:
# tensor(11.)

# %% [markdown]
# ### 练习3

# %%
import torch

x = torch.tensor(5.0, requires_grad=True)
y = x * 2
z = y.detach() * 3

print(z.requires_grad)
# Out:
# False

# %% [markdown]
# ### 练习4

# %%
import torch

a = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(2.0, requires_grad=True)
c = torch.tensor(3.0, requires_grad=True)
loss = (a * b + c) ** 2

loss.backward()

print(a.grad) # 2 * (a * b + c) * b = 20
print(b.grad) # 2 * (a * b + c) * a = 10
print(c.grad) # 2 * (a * b + c) = 10
# Out:
# tensor(20.)
# tensor(10.)
# tensor(10.)
